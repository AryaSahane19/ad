# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose

# Load your time series data (CSV file from GitHub)
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv'
data = pd.read_csv(url, parse_dates=['Month'], index_col='Month')

# Check the first few rows of the dataset
print(data.head())

# Check for stationarity (ADF test)
result = adfuller(data['Passengers'])
print('ADF Statistic:', result[0])
print('p-value:', result[1])

if result[1] <= 0.05:
    print("The series is stationary!")
else:
    print("The series is not stationary, differencing is required.")

# Decompose the series (Trend, Seasonality, Residuals)
decomposition = seasonal_decompose(data['Passengers'], model='additive', period=12)
decomposition.plot()
plt.show()

# Decompose the series (Trend, Seasonality, Residuals)
decomposition = seasonal_decompose(values, model='additive', period=12)
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Fit ARIMA model
model = ARIMA(data['Passengers'], order=(5, 1, 0))  # Example parameters (p, d, q)
fitted_model = model.fit()

# Forecast the next 12 months
forecast = fitted_model.forecast(steps=12)

# Plot the actual data and forecasted data
plt.figure(figsize=(10,6))
plt.plot(data['Passengers'], label='Actual')
plt.plot(pd.date_range(start=data.index[-1], periods=13, freq='M')[1:], forecast, label='Forecast', color='red')
plt.title('ARIMA Forecast: Airline Passengers')
plt.xlabel('Year')
plt.ylabel('Number of Passengers')
plt.legend()
plt.show()
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# ADF Statistic: 0.8153688792060597
# p-value: 0.9918802434376411
# The series is not stationary, differencing is required.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21656\2248692435.py in <module>
#      30
#      31 # Decompose the series (Trend, Seasonality, Residuals)
# ---> 32 decomposition = seasonal_decompose(values, model='additive', period=12)
#      33 trend = decomposition.trend
#      34 seasonal = decomposition.seasonal
#
# NameError: name 'values' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose

# Load your time series data (CSV file from GitHub)
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv'
data = pd.read_csv(url, parse_dates=['Month'], index_col='Month')

# Check the first few rows of the dataset
print(data.head())

# Check for stationarity (ADF test)
result = adfuller(data['Passengers'])
print('ADF Statistic:', result[0])
print('p-value:', result[1])

if result[1] <= 0.05:
    print("The series is stationary!")
else:
    print("The series is not stationary, differencing is required.")

# Decompose the series (Trend, Seasonality, Residuals)
decomposition = seasonal_decompose(data['Passengers'], model='additive', period=12)
decomposition.plot()
plt.show()

# Fit ARIMA model
model = ARIMA(data['Passengers'], order=(5, 1, 0))  # Example parameters (p, d, q)
fitted_model = model.fit()

# Forecast the next 12 months
forecast = fitted_model.forecast(steps=12)

# Plot the actual data and forecasted data
plt.figure(figsize=(10,6))
plt.plot(data['Passengers'], label='Actual')
plt.plot(pd.date_range(start=data.index[-1], periods=13, freq='M')[1:], forecast, label='Forecast', color='red')
plt.title('ARIMA Forecast: Airline Passengers')
plt.xlabel('Year')
plt.ylabel('Number of Passengers')
plt.legend()
plt.show()
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# ADF Statistic: 0.8153688792060597
# p-value: 0.9918802434376411
# The series is not stationary, differencing is required.
# C:\Users\Arya Sahane\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Arya Sahane\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Arya Sahane\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
